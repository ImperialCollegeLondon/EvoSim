# %% [markdown]
# This examples shows how to use the python API to:
#
# 1. Create a fleet of electric vehicles
# 1. Create a charging-post infrastructure
# 1. Create a constraint
# 1. Allocate fleet to infrastructure under some constraints
# 1. Plot the density profile of distances from vehicle destination to charging post

# %% [markdown]
# # Setting up the fleet, infrastructure, and constraint
# First we create the fleet. It is simply a pandas data-frame with a specific set of
# attributes (one attribute per column).  More attributes/columns can be added if
# required for a specific application.  Here, we generate the fleet randomly with a
# fairly minimal set. Run `evosim.fleet.random_fleet?` in a code-cell to see how to
# parametrize the random generation. The ``seed`` argument is optional. We give it here
# to ensure this notebook runs reproducibly during the tests and does not interfere with
# version control.

# %%
import numpy as np

import evosim

rng = np.random.default_rng(2)
fleet = evosim.fleet.random_fleet(1000, seed=rng)
fleet
# Out:
#      latitude  longitude            socket charger  dest_lat  dest_long                      model
# 0       51.37       0.93           CHADEMO    SLOW     51.55       0.96            SMART_EQ_FORTWO
# 1       51.38       0.26               CCS    FAST     51.49       0.04      VOLVO_V90_TWIN_ENGINE
# 2       51.62       0.13             TYPE1    FAST     51.39       1.14              TESLA_MODEL_S
# 3       51.29      -0.15             TYPE1    SLOW     51.32      -0.28                 BMW_X5_40E
# 4       51.52       0.90  THREE_PIN_SQUARE    FAST     51.28       1.00                NISSAN_LEAF
# 5       51.58       0.38           CHADEMO    FAST     51.55       0.36                  BMW_225XE
# 6       51.33       1.03               CCS    SLOW     51.53       0.60                    UNKNOWN
# 7       51.27       0.36             TYPE1    FAST     51.50       0.44        MERCEDES_BENZ_C350E
# 8       51.37       1.03             TYPE1    SLOW     51.51       0.13     HYUNDAI_IONIQ_ELECTRIC
# 9       51.55       0.76             TYPE1   RAPID     51.66       0.98                RENAULT_ZOE
# 10      51.50       0.50    DC_COMBO_TYPE2   RAPID     51.69       0.65              TESLA_MODEL_S
# 11      51.32       0.79               CCS    SLOW     51.42      -0.22                RENAULT_ZOE
# 12      51.44       0.79           CHADEMO    FAST     51.36       0.61              TESLA_MODEL_S
# 13      51.55      -0.42             TYPE1    SLOW     51.33       0.32                    UNKNOWN
# 14      51.44       0.92               CCS    FAST     51.34       0.82     HYUNDAI_IONIQ_ELECTRIC
# 15      51.53      -0.31             TYPE1   RAPID     51.68       0.78              KIA_NIRO_PHEV
# 16      51.69       0.45    DC_COMBO_TYPE2    FAST     51.46       0.26                   BMW_330E
# 17      51.56       0.35           CHADEMO    FAST     51.34       0.49              TESLA_MODEL_X
# 18      51.43       0.83    DC_COMBO_TYPE2    SLOW     51.35      -0.15        TOYOTA_PRIUS_PLUGIN
# 19      51.33      -0.12             TYPE2    SLOW     51.55       0.04     HYUNDAI_IONIQ_ELECTRIC
# 20      51.41       0.72             TYPE1    FAST     51.47       0.04           SMART_EQ_FORFOUR
# 21      51.48       0.88  THREE_PIN_SQUARE    FAST     51.58       1.03                   BMW_330E
# 22      51.65       0.10    DC_COMBO_TYPE2    FAST     51.69       0.27            SMART_EQ_FORTWO
# ..        ...        ...               ...     ...       ...        ...                        ...
# 977     51.46      -0.49           CHADEMO    SLOW     51.30      -0.32                     BMW_I3
# 978     51.34       0.94             TYPE2    SLOW     51.45       0.31                  BMW_225XE
# 979     51.69      -0.03  THREE_PIN_SQUARE    SLOW     51.56       0.55           SMART_EQ_FORFOUR
# 980     51.39       0.14             TYPE1   RAPID     51.49       0.77     VOLVO_XC60_TWIN_ENGINE
# 981     51.63       0.86  THREE_PIN_SQUARE    SLOW     51.64      -0.44     VOLVO_XC60_TWIN_ENGINE
# 982     51.59       0.90  THREE_PIN_SQUARE    SLOW     51.45       0.15     HYUNDAI_IONIQ_ELECTRIC
# 983     51.26       0.43             TYPE1    FAST     51.45       0.46  MINI_COUNTRYMAN_COOPER_SE
# 984     51.27       1.01  THREE_PIN_SQUARE    FAST     51.61       0.12                NISSAN_LEAF
# 985     51.45       0.31           CHADEMO    FAST     51.29      -0.10              TESLA_MODEL_S
# 986     51.26       0.24           CHADEMO   RAPID     51.27      -0.16      VOLVO_V90_TWIN_ENGINE
# 987     51.66       0.58  THREE_PIN_SQUARE   RAPID     51.34       1.15     HYUNDAI_IONIQ_ELECTRIC
# 988     51.69       0.42             TYPE2    SLOW     51.63       1.00                     BMW_I3
# 989     51.53      -0.03             TYPE1    FAST     51.57       0.09     HYUNDAI_IONIQ_ELECTRIC
# 990     51.39       0.80  THREE_PIN_SQUARE   RAPID     51.54       0.98        MERCEDES_BENZ_E350E
# 991     51.35       0.68  THREE_PIN_SQUARE    SLOW     51.37      -0.27        MERCEDES_BENZ_E350E
# 992     51.31      -0.22               CCS    SLOW     51.47       0.58             CITROEN_C_ZERO
# 993     51.51       0.49           CHADEMO   RAPID     51.35       0.95                   BMW_330E
# 994     51.32       0.41           CHADEMO    SLOW     51.29      -0.35                   BMW_330E
# 995     51.35       0.47           CHADEMO    SLOW     51.35       0.73     HYUNDAI_IONIQ_ELECTRIC
# 996     51.57       0.48  THREE_PIN_SQUARE    SLOW     51.28      -0.11                RENAULT_ZOE
# 997     51.64       0.70               CCS    SLOW     51.59       0.15  MINI_COUNTRYMAN_COOPER_SE
# 998     51.53       0.28  THREE_PIN_SQUARE    FAST     51.29       0.93            SMART_EQ_FORTWO
# 999     51.68       0.41             TYPE2   RAPID     51.57       1.11     VOLVO_XC90_TWIN_ENGINE
#
# [1000 rows x 7 columns]

# %% [markdown]
# Then we create the infrastructure of charging posts. Again, it is just a pandas
# data-frame with a specific set of columns. And again, it is filled with mostly random
# data. Arbitrarily, we've decided the capacity of the posts would range from 1 to 5 and
# the occupancy from 0 to 2.

# %%
infrastructure = evosim.charging_posts.random_charging_posts(
    len(fleet) // 3, capacity=5, occupancy=2, seed=rng
)
infrastructure
# Out:
#      latitude  longitude            socket charger  capacity  occupancy
# 0       51.39      -0.13             TYPE2    SLOW         3          2
# 1       51.36      -0.30             TYPE1    SLOW         1          0
# 2       51.26       1.20             TYPE1    SLOW         4          0
# 3       51.63      -0.48    DC_COMBO_TYPE2    SLOW         1          0
# 4       51.67       0.65    DC_COMBO_TYPE2   RAPID         4          0
# 5       51.41       0.05    DC_COMBO_TYPE2    FAST         1          0
# 6       51.31       0.50    DC_COMBO_TYPE2    FAST         4          1
# 7       51.53       0.92    DC_COMBO_TYPE2    SLOW         2          0
# 8       51.68       0.10             TYPE1    FAST         3          1
# 9       51.41       0.97    DC_COMBO_TYPE2    FAST         4          1
# 10      51.45       0.49             TYPE2    FAST         2          0
# 11      51.34       0.84             TYPE1    FAST         3          0
# 12      51.42      -0.32               CCS    SLOW         1          0
# 13      51.55       1.17  THREE_PIN_SQUARE    FAST         5          0
# 14      51.68       0.80             TYPE1    SLOW         4          0
# 15      51.34      -0.30    DC_COMBO_TYPE2    SLOW         5          2
# 16      51.34      -0.01             TYPE2    SLOW         2          0
# 17      51.66       0.99  THREE_PIN_SQUARE    SLOW         1          0
# 18      51.52       0.17               CCS   RAPID         1          0
# 19      51.49       1.07           CHADEMO   RAPID         4          2
# 20      51.30      -0.05               CCS   RAPID         5          1
# 21      51.63       0.71    DC_COMBO_TYPE2    FAST         5          0
# 22      51.32       0.47               CCS    FAST         3          2
# ..        ...        ...               ...     ...       ...        ...
# 310     51.65       0.99  THREE_PIN_SQUARE    FAST         4          1
# 311     51.53       0.85             TYPE2   RAPID         5          0
# 312     51.54       0.48             TYPE2   RAPID         5          0
# 313     51.26       0.06  THREE_PIN_SQUARE   RAPID         5          0
# 314     51.32       0.20             TYPE2   RAPID         3          0
# 315     51.28       0.11               CCS   RAPID         2          0
# 316     51.29       0.12           CHADEMO    SLOW         1          0
# 317     51.60      -0.34  THREE_PIN_SQUARE    SLOW         3          2
# 318     51.25       0.21             TYPE1   RAPID         5          1
# 319     51.53      -0.33             TYPE1    FAST         3          0
# 320     51.69      -0.28    DC_COMBO_TYPE2    SLOW         1          0
# 321     51.49       0.18    DC_COMBO_TYPE2    FAST         3          1
# 322     51.53      -0.12             TYPE2    SLOW         3          2
# 323     51.26       1.03               CCS   RAPID         5          1
# 324     51.42      -0.04  THREE_PIN_SQUARE    SLOW         4          1
# 325     51.28      -0.18  THREE_PIN_SQUARE   RAPID         5          0
# 326     51.33      -0.19             TYPE1   RAPID         1          0
# 327     51.60       0.93  THREE_PIN_SQUARE    SLOW         4          1
# 328     51.48      -0.33  THREE_PIN_SQUARE   RAPID         2          1
# 329     51.43       0.46    DC_COMBO_TYPE2   RAPID         5          0
# 330     51.57       0.98  THREE_PIN_SQUARE    FAST         4          1
# 331     51.41       0.97  THREE_PIN_SQUARE   RAPID         5          0
# 332     51.60       0.09             TYPE1    FAST         2          0
#
# [333 rows x 6 columns]

# %% [markdown]
# The random generation algorithm is smart enough to ensure the occupancy is always
# smaller or equal to the capacity.

# %%
assert (infrastructure.occupancy <= infrastructure.capacity).all()

# %% [markdown]
# Now we can create a ``matcher`` function: a constraint which allows or disallows
# matching an electric vehicle with a charging post. Individual matchers can be found in
# ``evosim.matchers``. But there is also a factory function which helps to generate a
# matcher function that is a combination of individual matchers. They are combined with
# ``and`` logic: all individual constraints must be true for the match to be okayed.

# %%
matcher = evosim.matchers.factory(["socket_compatibility", "charger_compatibility"])

# %% [markdown]
# We can match a single vehicle to a single post

# %%
matcher(fleet.loc[0], infrastructure.loc[1])
# Out:
# <Sockets.0: 0>

# %% [markdown]
# Or the full fleet to a single post

# %%
matcher(fleet, infrastructure.loc[1])
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# 979    False
# 980    False
# 981    False
# 982    False
# 983    False
# 984    False
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992    False
# 993    False
# 994    False
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# Or a single vehicle to the full infrastructure

# %%
matcher(fleet.loc[1], infrastructure)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22      True
# 23     False
# 24     False
# 25     False
#        ...
# 307    False
# 308    False
# 309    False
# 310    False
# 311    False
# 312    False
# 313    False
# 314    False
# 315    False
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# 321    False
# 322    False
# 323    False
# 324    False
# 325    False
# 326    False
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# 332    False
# Length: 333, dtype: bool

# %% [markdown]
# Or we can match fleet and infrastructure element-wise: the first vehicle to the first
# post, the second to the second, and so on. However, this element-wise comparison only
# works if there are as many rows in fleet as in infrastructure. At time of writing, the
# error thrown by pandas is not particularly enlightening:

# %%
try:
    matcher(fleet, infrastructure)
except TypeError as e:
    print("Yup, we got an error: ", e)
# Out:
# Yup, we got an error:  unsupported operand type(s) for &: 'Sockets' and 'bool'

# %% [markdown]
# But we can make the comparison work as follows:

# %%
matcher(fleet.iloc[: len(infrastructure)], infrastructure)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
#        ...
# 307    False
# 308     True
# 309    False
# 310    False
# 311    False
# 312     True
# 313    False
# 314    False
# 315    False
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# 321    False
# 322    False
# 323    False
# 324    False
# 325    False
# 326    False
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# 332    False
# Length: 333, dtype: bool

# %% [markdown]
# # Running the allocation algorithm
# The matcher can be used to constrain the allocation of vehicles to posts. Below, we
# use the *random* allocator for this purpose. It allocates any vehicle to any post, as
# long as the matcher okays it:

# %%
fleet_allocation = evosim.allocators.random_allocator(fleet, infrastructure, matcher)
fleet_allocation
# Out:
#      latitude  longitude            socket  ... dest_long                      model  allocation
# 0       51.37       0.93           CHADEMO  ...      0.96            SMART_EQ_FORTWO         110
# 1       51.38       0.26               CCS  ...      0.04      VOLVO_V90_TWIN_ENGINE         163
# 2       51.62       0.13             TYPE1  ...      1.14              TESLA_MODEL_S          81
# 3       51.29      -0.15             TYPE1  ...     -0.28                 BMW_X5_40E          14
# 4       51.52       0.90  THREE_PIN_SQUARE  ...      1.00                NISSAN_LEAF         151
# 5       51.58       0.38           CHADEMO  ...      0.36                  BMW_225XE         227
# 6       51.33       1.03               CCS  ...      0.60                    UNKNOWN        <NA>
# 7       51.27       0.36             TYPE1  ...      0.44        MERCEDES_BENZ_C350E         178
# 8       51.37       1.03             TYPE1  ...      0.13     HYUNDAI_IONIQ_ELECTRIC         307
# 9       51.55       0.76             TYPE1  ...      0.98                RENAULT_ZOE         214
# 10      51.50       0.50    DC_COMBO_TYPE2  ...      0.65              TESLA_MODEL_S        <NA>
# 11      51.32       0.79               CCS  ...     -0.22                RENAULT_ZOE        <NA>
# 12      51.44       0.79           CHADEMO  ...      0.61              TESLA_MODEL_S         120
# 13      51.55      -0.42             TYPE1  ...      0.32                    UNKNOWN        <NA>
# 14      51.44       0.92               CCS  ...      0.82     HYUNDAI_IONIQ_ELECTRIC        <NA>
# 15      51.53      -0.31             TYPE1  ...      0.78              KIA_NIRO_PHEV         218
# 16      51.69       0.45    DC_COMBO_TYPE2  ...      0.26                   BMW_330E          91
# 17      51.56       0.35           CHADEMO  ...      0.49              TESLA_MODEL_X        <NA>
# 18      51.43       0.83    DC_COMBO_TYPE2  ...     -0.15        TOYOTA_PRIUS_PLUGIN         261
# 19      51.33      -0.12             TYPE2  ...      0.04     HYUNDAI_IONIQ_ELECTRIC         276
# 20      51.41       0.72             TYPE1  ...      0.04           SMART_EQ_FORFOUR         121
# 21      51.48       0.88  THREE_PIN_SQUARE  ...      1.03                   BMW_330E         267
# 22      51.65       0.10    DC_COMBO_TYPE2  ...      0.27            SMART_EQ_FORTWO         321
# ..        ...        ...               ...  ...       ...                        ...         ...
# 977     51.46      -0.49           CHADEMO  ...     -0.32                     BMW_I3         254
# 978     51.34       0.94             TYPE2  ...      0.31                  BMW_225XE        <NA>
# 979     51.69      -0.03  THREE_PIN_SQUARE  ...      0.55           SMART_EQ_FORFOUR         132
# 980     51.39       0.14             TYPE1  ...      0.77     VOLVO_XC60_TWIN_ENGINE         171
# 981     51.63       0.86  THREE_PIN_SQUARE  ...     -0.44     VOLVO_XC60_TWIN_ENGINE         190
# 982     51.59       0.90  THREE_PIN_SQUARE  ...      0.15     HYUNDAI_IONIQ_ELECTRIC         295
# 983     51.26       0.43             TYPE1  ...      0.46  MINI_COUNTRYMAN_COOPER_SE         300
# 984     51.27       1.01  THREE_PIN_SQUARE  ...      0.12                NISSAN_LEAF        <NA>
# 985     51.45       0.31           CHADEMO  ...     -0.10              TESLA_MODEL_S         205
# 986     51.26       0.24           CHADEMO  ...     -0.16      VOLVO_V90_TWIN_ENGINE        <NA>
# 987     51.66       0.58  THREE_PIN_SQUARE  ...      1.15     HYUNDAI_IONIQ_ELECTRIC         291
# 988     51.69       0.42             TYPE2  ...      1.00                     BMW_I3         276
# 989     51.53      -0.03             TYPE1  ...      0.09     HYUNDAI_IONIQ_ELECTRIC         297
# 990     51.39       0.80  THREE_PIN_SQUARE  ...      0.98        MERCEDES_BENZ_E350E         155
# 991     51.35       0.68  THREE_PIN_SQUARE  ...     -0.27        MERCEDES_BENZ_E350E         327
# 992     51.31      -0.22               CCS  ...      0.58             CITROEN_C_ZERO        <NA>
# 993     51.51       0.49           CHADEMO  ...      0.95                   BMW_330E          58
# 994     51.32       0.41           CHADEMO  ...     -0.35                   BMW_330E        <NA>
# 995     51.35       0.47           CHADEMO  ...      0.73     HYUNDAI_IONIQ_ELECTRIC        <NA>
# 996     51.57       0.48  THREE_PIN_SQUARE  ...     -0.11                RENAULT_ZOE        <NA>
# 997     51.64       0.70               CCS  ...      0.15  MINI_COUNTRYMAN_COOPER_SE        <NA>
# 998     51.53       0.28  THREE_PIN_SQUARE  ...      0.93            SMART_EQ_FORTWO         330
# 999     51.68       0.41             TYPE2  ...      1.11     VOLVO_XC90_TWIN_ENGINE         245
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Analysis and plots
# We are now in a position to analyse the results. First we will take a look at the
# unallocated vehicles. Then we will plot the distribution of distances from each
# vehicles destination to each charging post.
# Allocated and unallocated vehicles can be obtained as:

# %%
unallocated_fleet = fleet[fleet_allocation.allocation.isna()]
allocated_fleet = fleet_allocation[~fleet_allocation.allocation.isna()]

# %% [markdown]
# We can update the infrastructure to account for newly occupied posts. Note that the
# infrastructure is copied with ``deep=True`` to ensure that changing the occupancy in
# ``new_infrastructure`` does not affect the original dataframe.

# %%
new_infrastructure = infrastructure.copy(deep=True)
new_occupancy = allocated_fleet.groupby("allocation").allocation.count()
new_infrastructure.loc[new_occupancy.index, "occupancy"] += new_occupancy

# %% [markdown]
# Now we plot the number allocated and unallocated infrastructure and vehicles

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

output_notebook()
allocation_data = {
    "type": ["Initial Infrastructure", "Final Infrastructure", "Fleet"],
    "allocated": [
        infrastructure.occupancy.sum(),
        new_infrastructure.occupancy.sum(),
        len(allocated_fleet),
    ],
    "unallocated": [
        (infrastructure.capacity - infrastructure.occupancy).sum(),
        (new_infrastructure.capacity - new_infrastructure.occupancy).sum(),
        len(allocated_fleet),
    ],
}

barplot = figure(
    x_range=allocation_data["type"],
    height=200,
    title="Infrastructure and vehicle allocation",
)
barplot.vbar_stack(
    ["allocated", "unallocated"],
    x="type",
    width=0.9,
    source=allocation_data,
    color=["darkgrey", "lightgrey"],
    alpha=[1, 0.5],
    legend_label=["allocated", "unallocated"],
)
barplot.y_range.start = 0
barplot.legend.location = "top_left"
barplot.legend.orientation = "horizontal"
show(barplot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="54f46a43-a2a4-4d0a-9ef3-de7d4218db4c" data-root-id="1002"></div>

# %% [markdown]
# To plot the density profile, we need the distance from the vehicle destinations to the
# allocated charging posts. We use the ``evosim``'s objective function for that purpose.
# The objective function expects two dataframe arguments, each with a "latitude" and a
# "longitude" column. Hence, we first rename the destination columns of the
# ``allocated_fleet``. Also note that since the objective function compares dataframes,
# they must conform to the same index.

# %%
distance = evosim.objectives.distance(
    (
        allocated_fleet[["dest_lat", "dest_long"]].rename(
            columns=dict(dest_lat="latitude", dest_long="longitude")
        )
    ),
    infrastructure.loc[allocated_fleet.allocation].set_index(allocated_fleet.index),
)

density_plot = figure(title="Distance to charging post",)
y, x = np.histogram(distance, bins=20)
density_plot.line((x[1:] + x[:-1]) / 2, y)
show(density_plot)
# Out:
#   <div class="bk-root" id="74cd2e26-9a5f-4249-879d-f7ea42ef32c9" data-root-id="1131"></div>
